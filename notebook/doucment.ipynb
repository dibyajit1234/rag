# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata={"author": "John Doe", "pages":1,"source":"example.txt","date_created":"2024-06-01"},
)
doc
# Out:
# Document(metadata={'author': 'John Doe', 'pages': 1, 'source': 'example.txt', 'date_created': '2024-06-01'}, page_content='This is the content of the document.')

# %%
import os
os.makedirs("data/text_files",exist_ok=True)

# %%
sample_texts = {
    "data/text_files/minecraft.txt":""" ❗ Why You Can't Get Exact Nether Fortress Coordinates in Jartex
✔ Every Survival world has a unique seed

Jartex uses a custom world seed that is NOT public, so fortress locations cannot be predicted.

✔ Fortresses generate RANDOMLY in each world

Every SMP/Survival reset = brand-new fortress positions.

✔ Staff does NOT reveal fortress coordinates

To keep the server fair and prevent griefing.

So unfortunately, nobody can give you real coordinates.

✅ How YOU Can Find a Nether Fortress on Jartex (Works Every Time)
1️⃣ Go in the positive X or negative X direction

Nether structures generate in strips every ~400 blocks along the X-axis.

So travel:

+X direction
or

–X direction

You will ALWAYS hit a fortress eventually.

2️⃣ Stay between Y = 60–70

This height lets you see bridges more easily and avoid lava oceans.

3️⃣ Use this search pattern

Move in straight lines:

Walk 200–300 blocks in +X

If no fortress → move 100 blocks in +Z or –Z

Continue in +X or –X

This scans the Nether efficiently.

4️⃣ Look for signs of a fortress

Watch for:

Long nether brick bridges

Wither skeletons

Blaze spawners

Big rectangular rooms

🔥 Pro Tip (Jartex-Specific)

Jartex often has other players who already explored near spawn.
So your best chance is to use:

➤ /rtp → then build a small Nether portal

You’ll land in a fresh Nether area with a higher chance of finding a fortress.

⭐ If you want, I can:

✅ Give you a step-by-step pathfinding method to locate fortresses faster
✅ Tell you how to find Bastions also
Just tell me!"""
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding='utf-8') as f:
        f.write(content)
print("minecraft file created")
# Out:
# minecraft file created

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("data/text_files/minecraft.txt",encoding='utf-8')
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': 'data/text_files/minecraft.txt'}, page_content=" ❗ Why You Can't Get Exact Nether Fortress Coordinates in Jartex\n✔ Every Survival world has a unique seed\n\nJartex uses a custom world seed that is NOT public, so fortress locations cannot be predicted.\n\n✔ Fortresses generate RANDOMLY in each world\n\nEvery SMP/Survival reset = brand-new fortress positions.\n\n✔ Staff does NOT reveal fortress coordinates\n\nTo keep the server fair and prevent griefing.\n\nSo unfortunately, nobody can give you real coordinates.\n\n✅ How YOU Can Find a Nether Fortress on Jartex (Works Every Time)\n1️⃣ Go in the positive X or negative X direction\n\nNether structures generate in strips every ~400 blocks along the X-axis.\n\nSo travel:\n\n+X direction\nor\n\n–X direction\n\nYou will ALWAYS hit a fortress eventually.\n\n2️⃣ Stay between Y = 60–70\n\nThis height lets you see bridges more easily and avoid lava oceans.\n\n3️⃣ Use this search pattern\n\nMove in straight lines:\n
# ...

# %%
###Directory loader
from langchain_community.document_loaders import DirectoryLoader

##load all text files from directory
dir_loader = DirectoryLoader(
    "data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)
doc=dir_loader.load()
print(doc)
# Out:
# [Document(metadata={'source': 'data/text_files/minecraft.txt'}, page_content=" ❗ Why You Can't Get Exact Nether Fortress Coordinates in Jartex\n✔ Every Survival world has a unique seed\n\nJartex uses a custom world seed that is NOT public, so fortress locations cannot be predicted.\n\n✔ Fortresses generate RANDOMLY in each world\n\nEvery SMP/Survival reset = brand-new fortress positions.\n\n✔ Staff does NOT reveal fortress coordinates\n\nTo keep the server fair and prevent griefing.\n\nSo unfortunately, nobody can give you real coordinates.\n\n✅ How YOU Can Find a Nether Fortress on Jartex (Works Every Time)\n1️⃣ Go in the positive X or negative X direction\n\nNether structures generate in strips every ~400 blocks along the X-axis.\n\nSo travel:\n\n+X direction\nor\n\n–X direction\n\nYou will ALWAYS hit a fortress eventually.\n\n2️⃣ Stay between Y = 60–70\n\nThis height lets you see bridges more easily and avoid lava oceans.\n\n3️⃣ Use this search pattern\n\nMove in straight lines:\n
# ...

# %%
###Directory loader
from langchain_community.document_loaders import PyMuPDFLoader

##load all text files from directory
dir_loader = DirectoryLoader(
    "data/pdf_files",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)
pdf_doc=dir_loader.load()
print(pdf_doc)
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': 'data/pdf_files/Document from sayan_removed (1).pdf', 'file_path': 'data/pdf_files/Document from sayan_removed (1).pdf', 'total_pages': 12, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-10-27T15:19:09+00:00', 'trapped': '', 'modDate': 'D:20251027151909Z', 'creationDate': '', 'page': 0}, page_content='82 \nPossible questions from Study Materials \nQB  \nSl. No. \nQuestion \nQuestion \nMarks \n \nModule 3 \n \n1 \nDefine Grammar with an example  \n2 \n2 \n Define regular grammar with an example. \n2 \n3 \n Define context-free grammar with an example. \n2 \n4 \n Define Chomsky Normal Form with an example \n2 \n5 \n Define Greibach Normal Form with an example. \n2 \n6 \n Define ambiguous grammar with an example. \n2 \n7 \n Define derivation tree with an example. \n2 \n8 \n Define left most derivation with an example. \n2 \n9 \n Define right most deriv
# ...

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path="/home/dibyajit/Desktop/rag/data/csv_files/Shakespeare_data.csv")

data = loader.load()

print(data[:5])
# Out:
# [Document(metadata={'source': '/home/dibyajit/Desktop/rag/data/csv_files/Shakespeare_data.csv', 'row': 0}, page_content='Dataline: 1\nPlay: Henry IV\nPlayerLinenumber: \nActSceneLine: \nPlayer: \nPlayerLine: ACT I'), Document(metadata={'source': '/home/dibyajit/Desktop/rag/data/csv_files/Shakespeare_data.csv', 'row': 1}, page_content='Dataline: 2\nPlay: Henry IV\nPlayerLinenumber: \nActSceneLine: \nPlayer: \nPlayerLine: SCENE I. London. The palace.'), Document(metadata={'source': '/home/dibyajit/Desktop/rag/data/csv_files/Shakespeare_data.csv', 'row': 2}, page_content='Dataline: 3\nPlay: Henry IV\nPlayerLinenumber: \nActSceneLine: \nPlayer: \nPlayerLine: Enter KING HENRY, LORD JOHN OF LANCASTER, the EARL of WESTMORELAND, SIR WALTER BLUNT, and others'), Document(metadata={'source': '/home/dibyajit/Desktop/rag/data/csv_files/Shakespeare_data.csv', 'row': 3}, page_content='Dataline: 4\nPlay: Henry IV\nPlayerLinenumber: 1\nActSceneLine: 1.1.1\nPlayer: KING HENRY IV\nPlayerLine: So shaken
# ...
